# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()
#sns.set_style("dark")
#sns.set_style("whitegrid")

# %% [markdown]
# # Load Data

# %%
df = pd.read_csv('./data/glassdoor_cleaned.csv')
df.head(10)
# Out:
#    Rating          size                       ownership  \
# 0     4.5    201 to 500               Company - Private
# 1     4.5        10000+                Company - Public
# 2     4.5       1 to 50               Company - Private
# 3     3.6        10000+  Subsidiary or Business Segment
# 4     3.0   501 to 1000                Company - Public
# 5     3.5  1001 to 5000               Company - Private
# 6     3.4        10000+  Subsidiary or Business Segment
# 7     3.6  1001 to 5000          Nonprofit Organization
# 8     3.6        10000+  Subsidiary or Business Segment
# 9     3.6   501 to 1000                Company - Public
#
#                            industry                  sector  \
# 0                            others       Business Services
# 1                          Internet  Information Technology
# 2                            others       Business Services
# 3                       IT Services  Information Technology
# 4                            others                  others
# 5                Insurance Carriers               Insurance
# 6                Insurance Carriers               Insurance
# 7  Health Care Services & Hospitals             Health Care
# 8                       IT Services  Information Technology
# 9                            others                 Finance
#
#                       revenue  avg_salary  \
# 0          $25 to $50 million        86.0
# 1           $5 to $10 billion       125.0
# 2          $25 to $50 million        91.0
# 3                $10+ billion        75.5
# 4  $500 million to $1 billion        94.5
# 5            $1 to $2 billion        86.5
# 6                $10+ billion        89.5
# 7    Unknown / Non-Applicable        40.0
# 8                $10+ billion        56.0
# 9        $100 to $500 million       132.0
#
#                               company_text state  age  ...  hive  \
# 0                             Envision LLC    MO   26  ...     0
# 1                                 Facebook    DC   16  ...     1
# 2                         TechSource, Inc.    NM   -1  ...     0
# 3  General Dynamics Information Technology    VA   24  ...     0
# 4                           Medifast, Inc.    MD   40  ...     0
# 5       West Bend Mutual Insurance Company    WI  126  ...     0
# 6                                    GEICO    MD   84  ...     0
# 7     Children's Hospital & Medical Center    NE   72  ...     0
# 8  General Dynamics Information Technology    MD   24  ...     0
# 9                           Elevate Credit    TX    6  ...     0
#
#    deep_learning  nlp  cv  tensorflow  pytorch  keras    title_simple  \
# 0              0    0   0           0        0      0  data scientist
# 1              0    0   0           0        0      0  data scientist
# 2              0    0   0           0        0      0          others
# 3              0    0   0           0        0      0   data engineer
# 4              0    1   0           0        0      0  data scientist
# 5              0    0   0           0        0      0   data engineer
# 6              0    0   0           0        0      0   data engineer
# 7              0    0   0           0        0      0  data scientist
# 8              0    0   0           0        0      0  data scientist
# 9              0    0   0           0        0      0  data scientist
#
#    seniority  description
# 0     others          993
# 1     others         4680
# 2     others         5989
# 3     others         3323
# 4     senior         3126
# 5     others         1503
# 6     senior         3394
# 7     others         5348
# 8     others         6389
# 9     senior         2739
#
# [10 rows x 30 columns]

# %%
df.columns = [x.lower() for x in df.columns.values]

# %% [markdown]
# # helper functions

# %% [markdown]
# # EDA

# %% [markdown]
# ## Basic Info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 755 entries, 0 to 754
# Data columns (total 32 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   rating         755 non-null    float64
#  1   size           755 non-null    object
#  2   ownership      755 non-null    object
#  3   industry       755 non-null    object
#  4   sector         755 non-null    object
#  5   revenue        755 non-null    object
#  6   avg_salary     755 non-null    float64
#  7   company_text   755 non-null    object
#  8   state          755 non-null    object
#  9   age            755 non-null    int64
#  10  sql            755 non-null    int64
#  11  python         755 non-null    int64
#  12  java           755 non-null    int64
#  13  sas            755 non-null    int64
#  14  matlab         755 non-null    int64
#  15  javascript     755 non-null    int64
#  16  c++            755 non-null    int64
#  17  scala          755 non-null    int64
#  18  hadoop         755 non-null    int64
#  19  spark          755 non-null    int64
#  20  hive           755 non-null    int64
#  21  deep_learning  755 non-null    int64
#  22  nlp            755 non-null    int64
#  23  cv             755 non-null    int64
#  24  tensorflow     755 non-null    int64
#  25  pytorch        755 non-null    int64
#  26  keras          755 non-null    int64
#  27  title_simple   755 non-null    object
#  28  seniority      755 non-null    object
#  29  description    755 non-null    int64
#  30  rating_bin     755 non-null    category
#  31  age_bin        718 non-null    category
# dtypes: category(2), float64(2), int64(19), object(9)
# memory usage: 179.2+ KB

# %%
df.describe()
# Out:
#            rating  avg_salary         age         sql      python        java  \
# count  755.000000  755.000000  755.000000  755.000000  755.000000  755.000000
# mean     3.798940  111.049007   54.394702    0.468874    0.577483    0.190728
# std      0.526486   38.604825   65.100722    0.499361    0.494287    0.393136
# min     -1.000000   34.000000   -1.000000    0.000000    0.000000    0.000000
# 25%      3.500000   86.000000   13.000000    0.000000    0.000000    0.000000
# 50%      3.800000  107.000000   26.000000    0.000000    1.000000    0.000000
# 75%      4.100000  133.250000   73.000000    1.000000    1.000000    0.000000
# max      5.000000  342.500000  338.000000    1.000000    1.000000    1.000000
#
#               sas      matlab  javascript         c++  ...      hadoop  \
# count  755.000000  755.000000  755.000000  755.000000  ...  755.000000
# mean     0.128477    0.084768    0.042384    0.076821  ...    0.186755
# std      0.334842    0.278721    0.201597    0.266484  ...    0.389973
# min      0.000000    0.000000    0.000000    0.000000  ...    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000  ...    0.000000
# 50%      0.000000    0.000000    0.000000    0.000000  ...    0.000000
# 75%      0.000000    0.000000    0.000000    0.000000  ...    0.000000
# max      1.000000    1.000000    1.000000    1.000000  ...    1.000000
#
#             spark        hive  deep_learning         nlp          cv  \
# count  755.000000  755.000000     755.000000  755.000000  755.000000
# mean     0.209272    0.101987       0.099338    0.103311    0.029139
# std      0.407058    0.302832       0.299313    0.304567    0.168308
# min      0.000000    0.000000       0.000000    0.000000    0.000000
# 25%      0.000000    0.000000       0.000000    0.000000    0.000000
# 50%      0.000000    0.000000       0.000000    0.000000    0.000000
# 75%      0.000000    0.000000       0.000000    0.000000    0.000000
# max      1.000000    1.000000       1.000000    1.000000    1.000000
#
#        tensorflow     pytorch       keras   description
# count  755.000000  755.000000  755.000000    755.000000
# mean     0.076821    0.042384    0.047682   4144.003974
# std      0.266484    0.201597    0.213234   1707.837250
# min      0.000000    0.000000    0.000000    145.000000
# 25%      0.000000    0.000000    0.000000   3079.500000
# 50%      0.000000    0.000000    0.000000   3960.000000
# 75%      0.000000    0.000000    0.000000   5074.000000
# max      1.000000    1.000000    1.000000  15962.000000
#
# [8 rows x 21 columns]

# %%
df.describe(include='O')
# Out:
#           size         ownership                   industry  \
# count      755               755                        755
# unique       8                 6                         14
# top     10000+  Company - Public  Biotech & Pharmaceuticals
# freq       295               316                        193
#
#                            sector       revenue           company_text state  \
# count                         755           755                    755   755
# unique                         14            13                    380    36
# top     Biotech & Pharmaceuticals  $10+ billion  Takeda Pharmaceutical    CA
# freq                          193           197                     47   151
#
#           title_simple seniority
# count              755       755
# unique               4         5
# top     data scientist    others
# freq               636       535

# %% [markdown]
# ## Numeric Features

# %%
# Individual variables distribution
f,ax = plt.subplots(nrows=2, ncols=2, figsize=(20,12))
sns.distplot(df['avg_salary'], kde=False, ax=ax[0,0])
ax[0,0].set_xlabel('')
ax[0,0].set_title('Average Salary', fontsize=20)

sns.distplot(df['rating'], kde=False, ax=ax[0,1])
ax[0,1].set_xlabel('')
ax[0,1].set_title('Rating', fontsize=20)

sns.distplot(df['age'], kde=False, ax=ax[1,0])
ax[1,0].set_xlabel('')
ax[1,0].set_title('Company Age', fontsize=20)

sns.distplot(df['description'], kde=False, ax=ax[1,1])
ax[1,1].set_xlabel('')
ax[1,1].set_title('Job Description Length', fontsize=20)

plt.show()

# %% [markdown]
# * Average salary, Rating, and Job description length are almost normally distributed
# * Company age is right skewed, most company are fairly new, founded in last 50 years

# %%
# Correlation between numeric features
plt.figure(figsize=(10,8))
sns.heatmap(df[['avg_salary', 'rating', 'age', 'description']].corr(), annot=True, fmt = ".2f", \
            xticklabels=['Average Salary', 'Rating', 'Age', 'Description Length'], \
            yticklabels=['Average Salary', 'Rating', 'Age', 'Description Length'])

# %% [markdown]
# * avarage salary has some correlation with rating, not much with company age and description length
# * job description age positively related to age
# * rating is somehow negatively related with company age and job description length

# %%
# avarage salary by rating groups
bins = [-2,0,1,2,3,4,5]
df['rating_bin'] = pd.cut(df['rating'], bins=bins)
print(df['rating_bin'].value_counts())
sns.barplot(x='rating_bin', y='avg_salary', data=df[df['rating']>2])
plt.xlabel('Rating')
plt.ylabel('Average Salary')
plt.show()
# Out:
# (3, 4]     489
# (4, 5]     213
# (2, 3]      51
# (1, 2]       1
# (-2, 0]      1
# (0, 1]       0
# Name: rating_bin, dtype: int64

# %%
# avarage salary by age groups
bins = [0,10, 20,30, 50,100,200,500]
df['age_bin'] = pd.cut(df['age'], bins=bins)
print(df['age_bin'].value_counts())
sns.barplot(x='age_bin', y='avg_salary', data=df)
plt.xlabel('Age')
plt.ylabel('Average Salary')
plt.show()
# Out:
# (10, 20]      138
# (20, 30]      120
# (0, 10]       116
# (30, 50]      104
# (50, 100]      99
# (100, 200]     86
# (200, 500]     55
# Name: age_bin, dtype: int64

# %% [markdown]
# * Relatively new and old companies have higher average salary

# %% [markdown]
# ## Categorical Features

# %%
sns.set_style("dark")
def plot_bar_salary(col, figsize=(10, 6), rotate=False):
    """
    Print average salary by the group and the group count.
    col: column name
    figsize: figure size
    rotate: x axis label rotation angle
    """
    f, ax1 = plt.subplots(figsize=figsize)
    
    agg_data = df.groupby(col, as_index=False).agg({'avg_salary':['mean', 'count']})
    agg_data.columns = [col, 'Average Salary', 'Count']
    agg_data.sort_values(by='Average Salary', ascending=False, inplace=True)
    print(agg_data)
    
    sns.barplot(data=agg_data, x=col, y='Average Salary', ax=ax1, palette='Purples_d')
    ax2 = ax1.twinx() # This generates two separate y-axes that share the same x-axis.
    ax2.grid(False)
    sns.lineplot(data=agg_data, x=col, y='Count', ax=ax2, sort=False, color='yellow', marker='o')
    ax1.set_ylabel('Average Salary')
    ax1.set_title('Average Salary by {}'.format(col), fontsize=20)
    if rotate:
        ax1.set_xticklabels(ax1.get_xticklabels(), rotation=rotate, ha='right')
    ax2.set_ylabel('Count of {}'.format(col))
    ax2.set_ylim([0, None])

# %%
# averge salary by state
plot_bar_salary('state', figsize=(12, 8))
# Out:
#    state  Average Salary  Count
# 2     AZ      184.750000      2
# 3     CA      142.804636    151
# 5     CT      134.375000     20
# 14    MA      123.622340     94
# 26    NY      122.779070     43
# 22    NH      118.333333      3
# 11    IN      111.300000      5
# 9     GA      110.785714      7
# 6     DC      109.363636     22
# 17    MN      105.642857      7
# 31    TX      104.975610     41
# 23    NJ      102.793103     29
# 15    MD      100.869565     46
# 1     AR      100.500000      1
# 8     FL      100.428571     14
# 10    IL       98.243243     37
# 34    WA       94.810345     29
# 20    NC       91.416667     12
# 24    NM       91.000000      1
# 27    OH       90.933333     15
# 33    VA       90.896552     58
# 16    MI       90.535714     14
# 4     CO       89.800000      5
# 32    UT       87.566667     15
# 29    PA       87.350000     30
# 18    MO       84.937500     24
# 13    KY       79.500000      1
# 25    NV       79.250000      2
# 28    OR       78.833333      3
# 30    TN       77.666667      3
# 12    KS       76.000000      4
# 0     AL       74.833333      3
# 35    WI       71.136364     11
# 7     DE       62.000000      1
# 21    NE       40.000000      1
# 19    MS       39.500000      1

# %%
# average salary by size
plot_bar_salary('size', rotate=45)
# Out:
#             size  Average Salary  Count
# 7        Unknown      144.250000     10
# 4  5001 to 10000      130.425926     54
# 3     201 to 500      113.355140    107
# 5    501 to 1000      111.395161     62
# 6      51 to 200      109.919192     99
# 1         10000+      109.015254    295
# 2   1001 to 5000      105.490385    104
# 0        1 to 50       96.187500     24

# %% [markdown]
# * Start ups (size of 1-50) have the lowest average salary

# %%
# average salary by ownership
plot_bar_salary('ownership', rotate=45)
# Out:
#                         ownership  Average Salary  Count
# 2                      Government      116.093750     16
# 0               Company - Private      114.869010    313
# 1                Company - Public      113.227848    316
# 3          Nonprofit Organization       97.223404     47
# 4  Subsidiary or Business Segment       92.614583     48
# 5                           other       82.366667     15

# %%
# average salary by revenue
plot_bar_salary('revenue', figsize=(12, 8), rotate=45)
# Out:
#                        revenue  Average Salary  Count
# 1             $1 to $5 million      126.933333     30
# 0             $1 to $2 billion      121.397436     39
# 10  $500 million to $1 billion      121.314286     35
# 3                 $10+ billion      120.659898    197
# 12    Unknown / Non-Applicable      116.829932    147
# 8            $5 to $10 million      113.409091     11
# 4         $100 to $500 million      106.206522     92
# 2           $10 to $25 million      105.781250     16
# 7            $5 to $10 billion      105.347222     36
# 6           $25 to $50 million      100.911765     34
# 9          $50 to $100 million       96.904762     42
# 11        Less than $1 million       89.735294     17
# 5             $2 to $5 billion       77.618644     59

# %%
# average salary by skills
for col in ['sql', 'python', 'java',\
       'sas', 'matlab', 'javascript', 'c++', 'scala', 'hadoop', 'spark',\
       'hive', 'deep_learning', 'nlp', 'cv', 'tensorflow', 'pytorch', 'keras']:
    plot_bar_salary(col, figsize=(6,4))
# Out:
#    sql  Average Salary  Count
# 1    1      111.997175    354
# 0    0      110.211970    401
#    python  Average Salary  Count
# 1       1      115.670872    436
# 0       0      104.731975    319
#    java  Average Salary  Count
# 0     0      111.104746    611
# 1     1      110.812500    144
#    sas  Average Salary  Count
# 0    0      112.100304    658
# 1    1      103.917526     97
#    matlab  Average Salary  Count
# 1       1      111.132812     64
# 0       0      111.041245    691
#    javascript  Average Salary  Count
# 0           0      111.226141    723
# 1           1      107.046875     32
#    c++  Average Salary  Count
# 1    1      113.448276     58
# 0    0      110.849354    697
#    scala  Average Salary  Count
# 1      1      119.154696    181
# 0      0      108.493031    574
#    hadoop  Average Salary  Count
# 0       0      111.366450    614
# 1       1      109.666667    141
#    spark  Average Salary  Count
# 1      1      116.041139    158
# 0      0      109.727806    597
#    hive  Average Salary  Count
# 1     1      113.655844     77
# 0     0      110.752950    678
#    deep_learning  Average Salary  Count
# 0              0      111.315441    680
# 1              1      108.633333     75
#    nlp  Average Salary  Count
# 1    1      116.589744     78
# 0    0      110.410635    677
#    cv  Average Salary  Count
# 1   1      121.863636     22
# 0   0      110.724420    733
#    tensorflow  Average Salary  Count
# 1           1      116.405172     58
# 0           0      110.603300    697
#    pytorch  Average Salary  Count
# 1        1      114.703125     32
# 0        0      110.887275    723
#    keras  Average Salary  Count
# 1      1      113.305556     36
# 0      0      110.936022    719

# %%
# average salary by title
plot_bar_salary('title_simple', rotate=45)
# Out:
#      title_simple  Average Salary  Count
# 3          others      122.711538     26
# 2  data scientist      111.919811    636
# 1   data engineer      104.784884     86
# 0    data analyst       65.571429      7

# %%
# average salary by revenue
plot_bar_salary('seniority', rotate=45)
# Out:
#   seniority  Average Salary  Count
# 0  director      160.312500      8
# 4    senior      131.813107    206
# 2   manager      127.500000      4
# 3    others      102.342991    535
# 1    junior       71.250000      2

# %% [markdown]
# # Export features

# %%
df.columns
# Out:
# Index(['rating', 'size', 'ownership', 'industry', 'sector', 'revenue',
#        'avg_salary', 'company_text', 'state', 'age', 'sql', 'python', 'java',
#        'sas', 'matlab', 'javascript', 'c++', 'scala', 'hadoop', 'spark',
#        'hive', 'deep_learning', 'nlp', 'cv', 'tensorflow', 'pytorch', 'keras',
#        'title_simple', 'seniority', 'description', 'rating_bin', 'age_bin'],
#       dtype='object')
